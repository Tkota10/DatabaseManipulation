# %%
import pandas as pd

# %%
MarksDF = pd.read_csv("MarksData.csv")
MarksDF.head(30)
# Out:
#             RA          Dec     PmrA    PMDEC  sigPMRA  sigPMDEC  w1mpro_pm  \
# 0   359.906120   -8.8376156  0.12063  0.00614  0.01450    0.0145     15.239
# 1     0.295146   -9.5377627  0.46477 -0.28417  0.09770    0.0943     18.556
# 2     0.002239  -15.5800395 -0.00660  0.26086  0.06524    0.0038      9.416
# 3   359.610523  -15.8828579  0.12830 -0.04228  0.01450    0.0136     14.898
# 4   359.226041  -15.8893802 -0.43102 -0.69168  0.01490    0.0148     15.574
# 5   359.226267  -15.8890041 -0.50104 -0.79827  0.02420    0.0251     16.313
# 6   359.973032   -28.165985 -0.00670 -0.28520  0.03330    0.0357     17.051
# 7     0.573095  -29.6552676  0.13613 -0.00823  0.00940    0.0087     14.302
# 8   359.999839  -30.0244753  0.32629 -0.30010  0.00990    0.0093     14.405
# 9     0.392750  -33.2114349  0.20955 -0.02961  0.01400    0.0129     15.160
# 10  359.955176  -33.0254251  0.17384 -0.09089  0.01950    0.0173     15.554
# ...

# %%
VHSDF = pd.read_csv("VHS_Change")
VHSDF.head(37)
# Out:
#     upload_ID   upload_RA  upload_Dec  distance          ra        dec  \
# 0           0  359.906087   -8.837616  0.000000    0.000000   0.000000
# 1           1    0.295015   -9.537763  0.000000    0.000000   0.000000
# 2           2    0.002241  -15.580039  9.649282    0.004957 -15.579455
# 3           2    0.002241  -15.580039  0.404487    0.002133 -15.580083
# 4           3  359.610486  -15.882858  3.573147  359.611450 -15.883210
# 5           3  359.610486  -15.882858  0.423273  359.610505 -15.882742
# 6           3  359.610486  -15.882858  0.413641  359.610503 -15.882744
# 7           4  359.226165  -15.889380  1.269902  359.226251 -15.889037
# 8           5  359.226411  -15.889004  0.567500  359.226251 -15.889037
# 9           6  359.973034  -28.165985  0.000000    0.000000   0.000000
# 10          7    0.573052  -29.655268  0.000000    0.000000   0.000000
# 11          8  359.999734  -30.024475  0.000000    0.000000   0.000000
# ...

# %%
VHSDF[VHSDF.upload_ID == 3]
# Out:
#    upload_ID   upload_RA  upload_Dec  distance          ra        dec  \
# 4          3  359.610486  -15.882858  3.573147  359.611450 -15.883210
# 5          3  359.610486  -15.882858  0.423273  359.610505 -15.882742
# 6          3  359.610486  -15.882858  0.413641  359.610503 -15.882744
#
#       jAperMag3  jAperMag3Err    hAperMag3  hAperMag3Err    ksAperMag3  \
# 4 -9.999995e+08 -9.999995e+08 -999999500.0  -999999500.0 -9.999995e+08
# 5  1.578891e+01  5.764000e-03 -999999500.0  -999999500.0  1.513597e+01
# 6  1.577141e+01  6.164000e-03 -999999500.0  -999999500.0  1.513906e+01
#
#    ksAperMag3Err
# 4  -9.999995e+08
# 5   1.187300e-02
# 6   1.169700e-02

# %%
MarksDF.iloc[3]
# Out:
# RA                  359.611
# Dec             -15.8828579
# PmrA                 0.1283
# PMDEC              -0.04228
# sigPMRA              0.0145
# sigPMDEC             0.0136
# w1mpro_pm            14.898
# w1sigmpro_pm          0.018
# w2mpro_pm            14.948
# w2sigmpro_pm          0.034
# 2MASSRA              359.61
# 2MASSDEC           -15.8827
# j_m                  15.785
# j_msigcom            0.0671
# h_m                  15.239
# h_msigcom            0.0718
# k_m                  14.869
# k_msigcom            0.0926
# Unnamed: 18             NaN
# Name: 3, dtype: object

# %%
for index, row in MarksDF.iloc[0:8].iterrows():
    print(row.PMDEC)
# Out:
# 0.00614
# -0.28417
# 0.26086
# -0.04228
# -0.6916800000000001
# -0.79827
# -0.2852
# -0.00823
